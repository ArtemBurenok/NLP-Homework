# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemBurenok/NLP-Homework/blob/main/homework_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Full finished code, for reference

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16
block_size = 32
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('heart_of_dark.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]


def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y


@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out


# RMSNorm (замена LayerNorm)
class RMSNorm(nn.Module):
    def __init__(self, dim, eps=1e-8):
        super().__init__()
        self.eps = eps
        self.scale = nn.Parameter(torch.ones(dim))

    def forward(self, x):
        norm = x.norm(2, dim=-1, keepdim=True)
        rms = norm / (x.shape[-1] ** 0.5)
        return self.scale * x / (rms + self.eps)


# RoPE
def apply_rope(x):
    B, T, C = x.shape
    assert C % 2 == 0, "RoPE requires even hidden dimension"
    half = C // 2
    x1 = x[..., :half]
    x2 = x[..., half:]

    freq_seq = torch.arange(half, device=x.device)
    inv_freq = 1.0 / (10000 ** (freq_seq / half))
    pos = torch.arange(T, device=x.device)
    sinusoid = torch.einsum('i,j->ij', pos, inv_freq)
    sin, cos = sinusoid.sin(), sinusoid.cos()
    sin = sin[None, :, :]
    cos = cos[None, :, :]

    x1_rot = x1 * cos - x2 * sin
    x2_rot = x1 * sin + x2 * cos
    return torch.cat([x1_rot, x2_rot], dim=-1)


class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)
        q = self.query(x)
        k = apply_rope(k)
        q = apply_rope(q)
        wei = q @ k.transpose(-2,-1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out


class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out


# MoE (Mixture of Experts)
class MoE(nn.Module):
    def __init__(self, n_embd, num_experts=2):
        super().__init__()
        self.experts = nn.ModuleList([
            nn.Sequential(
                nn.Linear(n_embd, 4 * n_embd),
                nn.ReLU(),
                nn.Linear(4 * n_embd, n_embd)
            )
            for _ in range(num_experts)
        ])
        self.gate = nn.Linear(n_embd, num_experts)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        gate_scores = self.gate(x)  # (B,T,E)
        expert_idx = gate_scores.argmax(dim=-1)  # (B,T)

        out = torch.zeros_like(x)
        for i, expert in enumerate(self.experts):
            mask = (expert_idx == i)
            if mask.sum() > 0:
                expert_input = x[mask]
                expert_output = expert(expert_input)
                out[mask] = expert_output
        return self.dropout(out)


class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = MoE(n_embd, num_experts=2)
        self.ln1 = RMSNorm(n_embd)
        self.ln2 = RMSNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class BigramLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = RMSNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        x = tok_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)
        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx


model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.344105 M parameters
# step 0: train loss 4.6840, val loss 4.6798
# step 100: train loss 2.6775, val loss 2.6644
# step 200: train loss 2.4998, val loss 2.4784
# step 300: train loss 2.3721, val loss 2.3266
# step 400: train loss 2.2903, val loss 2.2646
# step 500: train loss 2.2246, val loss 2.1928
# step 600: train loss 2.1494, val loss 2.1400
# step 700: train loss 2.0952, val loss 2.0843
# step 800: train loss 2.0627, val loss 2.0704
# step 900: train loss 2.0278, val loss 2.0274
# step 1000: train loss 1.9987, val loss 2.0003
# step 1100: train loss 1.9827, val loss 1.9820
# step 1200: train loss 1.9650, val loss 1.9793
# step 1300: train loss 1.9465, val loss 1.9690
# step 1400: train loss 1.9190, val loss 1.9379
# step 1500: train loss 1.8898, val loss 1.9189
# step 1600: train loss 1.8773, val loss 1.9144
# step 1700: train loss 1.8674, val loss 1.9074
# step 1800: train loss 1.8500, val loss 1.9019
# step 1900: train loss 1.8316, val loss 1.8910
# step 2000: train loss 1.8196, val loss 1.8931
# step 2100: train loss 1.8130, val loss 1.8692
# step 2200: train loss 1.8014, val loss 1.8640
# step 2300: train loss 1.8038, val loss 1.8747
# step 2400: train loss 1.7721, val loss 1.8484
# step 2500: train loss 1.7613, val loss 1.8388
# step 2600: train loss 1.7653, val loss 1.8341
# step 2700: train loss 1.7469, val loss 1.8533
# step 2800: train loss 1.7388, val loss 1.8395
# step 2900: train loss 1.7364, val loss 1.8404
# step 3000: train loss 1.7191, val loss 1.8418
# step 3100: train loss 1.7142, val loss 1.8388
# step 3200: train loss 1.7138, val loss 1.8226
# step 3300: train loss 1.7086, val loss 1.8229
# step 3400: train loss 1.7151, val loss 1.8336
# step 3500: train loss 1.6964, val loss 1.8274
# step 3600: train loss 1.6851, val loss 1.8061
# step 3700: train loss 1.6883, val loss 1.7938
# step 3800: train loss 1.6782, val loss 1.8007
# step 3900: train loss 1.6638, val loss 1.8204
# step 4000: train loss 1.6629, val loss 1.8021
# step 4100: train loss 1.6671, val loss 1.7992
# step 4200: train loss 1.6626, val loss 1.8103
# step 4300: train loss 1.6401, val loss 1.7838
# step 4400: train loss 1.6431, val loss 1.7806
# step 4500: train loss 1.6343, val loss 1.7715
# step 4600: train loss 1.6373, val loss 1.7994
# step 4700: train loss 1.6178, val loss 1.7857
# step 4800: train loss 1.6153, val loss 1.7683
# step 4900: train loss 1.6113, val loss 1.7890
# step 4999: train loss 1.6066, val loss 1.7752
#
#         странствовать.
# Так ему моменно существа из в темноте, но, он пока
# назвянными  время  сустой.  На  его,  успоку  ет
# берег, словно конца. Нене было
# скрывал, небвавшибузнох мы вид его не посмотреть власться  пирал  я  время
# старой пустами были скрашало в мы успокоеланный и сюда  и  дего  набольше  пелу  гахом  и  тайе.  Все  может,  вдля  одним  осторебов!  В  шум  выраве.  Вы  шумение
# постерегатов.  Мрачен , что ж!..  отимяв  отхвая  судно
# делаться тому, когда его другоз кирюх с подумагим, и железяло бы известным, что себе. Можете. Его сердите вы только мы виде не постоитсь рассежение слабов; высоконечно не походие! Наливельным видел всю кусирия,  котвую  с  случае  сомне  изъежам,  у  последними  ссеким  каких
# желепов, показал я найтать и, он прогрыть начальника - сместовали у молстником древоде. Думающиеся мечаегу с каждино. Ну я зороки нельзя на рудо леса эти в проник,  казываясь  и  дрова
# Куртц. Пожетелепник...
#      Лагели.  И  думал  мили  как  происполницы
# перед
# щей судно и указывается на берег гартивая. Конечно, чем все всяка же поднимаю
# эти
# берегах ошествовать. Это
# дотов... хотивается деревья, как должен страчный  мишра.  Все  почивикм  душили  ничего  и  отделья  я  пустить.
#      - Прискликнул,
# но катартующий на черво  торговогать  в  этого
# краясь передавности, жарными
# осабным словно  может  глаза  у  соидей.
# Огневле лога. Сказать, у так он нему ишегуреку называет на были сильными ко прибыть во  изумлялись  не  обыкающей
# ног прошительными простерт, а постерливо дяра была назмвитем начальника в его-то этого из чторги. Ей день его не поверал иц! -  находились  повстреками,  ог,  сойви,
# иногды он меня спокойные кустам. Ничего налишност:
#      - Он черноком  же  начас;  и  голову.  Он,
# выжавбает.  Сличной  води.  В  к  кустахип?
#      Я отдал я, я сердяние извести. Видел, перехотелыми  из  гряз,  нечего  не  две  голови  от
# будет ведется терпел(ки любви его человек жестируку, кусты.  В  эту  предостоянием  перед  в,  все  или
# штаинской ходите,  чем  несколь
